# %%
import tensorflow as tf

# 建立一个线性回归的模型
class MyLinearRegression(object):
    """实现一个线性回归的训练"""
    def __init__(self):
        # 自己设定的学习率，如果学习率过大，那损失不会减小反而会增大，一般 0~1
        self.learning_rate = 0.005
        pass
    
    def inputs(self):
        """获取需要训练的数据"""
        # 因为要进行张量运算（矩阵）所以这里特指值定义成二维的
        # x:[100, 1]; y_true  x * 0.7 + 0.8
        x_data = tf.random_normal(shape=[100, 1], mean=0.0, stddev=1.0, name='x_data')
        # 假设不知道这个矩阵
        y_true = tf.matmul(x_data, [[0.7]]) + 0.8
        return x_data, y_true

    def inference(self, feature):
        """根据数据特征值建立线性回归模型，feature是特征值"""
        # 先定义一个命名空间避免混乱
        with tf.variable_scope("linear_model"):
            # w,b : x[100, 1] * w + b = y_predict
            # 随机初始化权重和偏置，注意，权重和偏置必须使用tf.Variable变量OP去定义，因为只有Variable才能被梯度下降（模型）所训练
            # 权重w应该是[1, 1]形状的矩阵，因为它参与了矩阵的乘法
            self.weight = tf.Variable(tf.random_normal(shape=[1, 1], mean=0.0, stddev=1.0), name="weight")
            # 偏置是直接加的，所以应该是[1]的形状
            self.bias = tf.Variable(tf.random_normal(shape=[1], mean=0.0, stddev=1.0), name="bias")
            # 建立模型预测
            y_predict = tf.matmul(feature, self.weight) + self.bias
        return y_predict
    
    def loss(self, y_true, y_predict):
        """根据预测值和真实值求出均方误差"""
        # 定义一个命名空间
        # sum((y_true-y_predict)^2)mean()
        with tf.variable_scope("losses"):
            # 求出损失
            # tf.reduce_mean()：对列表中的数据求和之后求平均值
            loss = tf.reduce_mean(tf.square(y_true - y_predict))       
        return loss
    
    def sgd_op(self, loss):
        """利用梯度下降优化器去优化损失(优化模型参数)"""
        # 定义一个命名空间
        with tf.variable_scope("train_op"):
            train_op = tf.train.GradientDescentOptimizer(self.learning_rate).minimize(loss)
        return train_op
    
    def merge_summary(self, loss):
        """定义收集张量的函数"""
        # 收集一些单值变量
        tf.summary.scalar("losses", loss)
        # 收集高维度的张量值
        tf.summary.histogram("w", self.weight)
        tf.summary.histogram("b", self.bias)
        # 合并变量（OP）
        merged = tf.summary.merge_all()
        return merged
    
    
    def train(self):
        """用于训练的函数"""
        # 获取默认的图
        g = tf.get_default_graph()
        # 在默认的图中进行操作
        with g.as_default():
            # 进行训练
            # 1.获取数据
            x_data, y_true = self.inputs()
            # 2.利用模型得出预测结果
            y_predict = self.inference(x_data)
            # 3.损失计算
            loss = self.loss(y_true, y_predict)
            # 4.优化损失
            train_op = self.sgd_op(loss)
            
            # 收集要观察的张量值
            merged = self.merge_summary(loss)
            
            
            # 开启会话运行训练
            with tf.Session() as sess:
                # 初始化变量
                sess.run(tf.global_variables_initializer())
                
                # 创建events文件
                file_writer = tf.summary.FileWriter("C:\\Users\\Administrator\\Git\\CFturb\\Deep_Learning\\tensorboard\\", graph=sess.graph)
                
                # 打印模型没有训练的初始化的参数
                print("模型初始化的参数权重：%f, 偏置为：%f" % (self.weight.eval(), self.bias.eval()))
                
                """由于只训练一次所以没有什么效果，那我们让它训练多次"""
                for i in range(2000):
                    # 接下来调用运行
                    _, summary = sess.run([train_op, merged])
                    # 把summary添加到文件
                    file_writer.add_summary(summary, i)
                    # 再打印一遍优化之后的参数 
                    print("第%d次模型优化后的参数权重：%f, 偏置为：%f, 损失为：%f" % (i, self.weight.eval(), self.bias.eval(), loss.eval()))
                    


# 运行整个程序
if __name__ == '__main__':
    lr = MyLinearRegression()
    lr.train()
# Out:
# 模型初始化的参数权重：0.502186, 偏置为：-0.071469
# 第0次模型优化后的参数权重：0.503215, 偏置为：-0.062896, 损失为：0.775692
# 第1次模型优化后的参数权重：0.504635, 偏置为：-0.054455, 损失为：0.737698
# 第2次模型优化后的参数权重：0.505573, 偏置为：-0.046084, 损失为：0.744641
# 第3次模型优化后的参数权重：0.506334, 偏置为：-0.037857, 损失为：0.672910
# 第4次模型优化后的参数权重：0.507551, 偏置为：-0.029676, 损失为：0.761395
# 第5次模型优化后的参数权重：0.509552, 偏置为：-0.021449, 损失为：0.618334
# 第6次模型优化后的参数权重：0.510548, 偏置为：-0.013442, 损失为：0.733983
# 第7次模型优化后的参数权重：0.511887, 偏置为：-0.005486, 损失为：0.695136
# 第8次模型优化后的参数权重：0.512213, 偏置为：0.002242, 损失为：0.663681
# 第9次模型优化后的参数权重：0.514131, 偏置为：0.010268, 损失为：0.677152
# 第10次模型优化后的参数权重：0.516223, 偏置为：0.018216, 损失为：0.667566
# 第11次模型优化后的参数权重：0.518100, 偏置为：0.026074, 损失为：0.586683
# 第12次模型优化后的参数权重：0.520654, 偏置为：0.033989, 损失为：0.607408
# 第13次模型优化后的参数权重：0.521731, 偏置为：0.041486, 损失为：0.610786
# 第14次模型优化后的参数权重：0.524105, 偏置为：0.049166, 损失为：0.589500
# 第15次模型优化后的参数权重：0.526970, 偏置为：0.056871, 损失为：0.575301
# 第16次模型优化后的参数权重：0.528587, 偏置为：0.064320, 损失为：0.620825
# 第17次模型优化后的参数权重：0.529153, 偏置为：0.071480, 损失为：0.585533
# 第18次模型优化后的参数权重：0.531860, 偏置为：0.078877, 损失为：0.530535
# 第19次模型优化后的参数权重：0.533694, 偏置为：0.086157, 损失为：0.496603
# 第20次模型优化后的参数权重：0.535451, 偏置为：0.093337, 损失为：0.536426
# 第21次模型优化后的参数权重：0.536998, 偏置为：0.100293, 损失为：0.488845
# 第22次模型优化后的参数权重：0.538280, 偏置为：0.107268, 损失为：0.490566
# 第23次模型优化后的参数权重：0.540831, 偏置为：0.114396, 损失为：0.475524
# 第24次模型优化后的参数权重：0.542764, 偏置为：0.121359, 损失为：0.478930
# 第25次模型优化后的参数权重：0.544021, 偏置为：0.128154, 损失为：0.472869
# 第26次模型优化后的参数权重：0.545407, 偏置为：0.134821, 损失为：0.490719
# 第27次模型优化后的参数权重：0.546554, 偏置为：0.141343, 损失为：0.449093
# 第28次模型优化后的参数权重：0.549035, 偏置为：0.148062, 损失为：0.488714
# 第29次模型优化后的参数权重：0.550510, 偏置为：0.154517, 损失为：0.416840
# 第30次模型优化后的参数权重：0.552572, 偏置为：0.161085, 损失为：0.401621
# 第31次模型优化后的参数权重：0.554126, 偏置为：0.167469, 损失为：0.378167
# 第32次模型优化后的参数权重：0.556052, 偏置为：0.173847, 损失为：0.424776
# 第33次模型优化后的参数权重：0.557627, 偏置为：0.180131, 损失为：0.400352
# 第34次模型优化后的参数权重：0.559417, 偏置为：0.186458, 损失为：0.416664
# 第35次模型优化后的参数权重：0.562139, 偏置为：0.192858, 损失为：0.415445
# 第36次模型优化后的参数权重：0.562772, 偏置为：0.198789, 损失为：0.352456
# 第37次模型优化后的参数权重：0.563835, 偏置为：0.204696, 损失为：0.404916
# 第38次模型优化后的参数权重：0.566672, 偏置为：0.210956, 损失为：0.398156
# 第39次模型优化后的参数权重：0.568411, 偏置为：0.216956, 损失为：0.351775
# 第40次模型优化后的参数权重：0.569524, 偏置为：0.222763, 损失为：0.356561
# 第41次模型优化后的参数权重：0.571305, 偏置为：0.228650, 损失为：0.364047
# 第42次模型优化后的参数权重：0.573161, 偏置为：0.234528, 损失为：0.342325
# 第43次模型优化后的参数权重：0.575559, 偏置为：0.240464, 损失为：0.329795
# 第44次模型优化后的参数权重：0.577418, 偏置为：0.246205, 损失为：0.331782
# 第45次模型优化后的参数权重：0.578066, 偏置为：0.251615, 损失为：0.320507
# 第46次模型优化后的参数权重：0.579305, 偏置为：0.257092, 损失为：0.330622
# 第47次模型优化后的参数权重：0.580090, 偏置为：0.262469, 损失为：0.292282
# 第48次模型优化后的参数权重：0.581555, 偏置为：0.267865, 损失为：0.291518
# 第49次模型优化后的参数权重：0.583444, 偏置为：0.273313, 损失为：0.292844
# 第50次模型优化后的参数权重：0.584695, 偏置为：0.278536, 损失为：0.298952
# 第51次模型优化后的参数权重：0.585812, 偏置为：0.283755, 损失为：0.280137
# 第52次模型优化后的参数权重：0.586472, 偏置为：0.288757, 损失为：0.273585
# 第53次模型优化后的参数权重：0.587398, 偏置为：0.293815, 损失为：0.262865
# 第54次模型优化后的参数权重：0.587828, 偏置为：0.298745, 损失为：0.248908
# 第55次模型优化后的参数权重：0.589693, 偏置为：0.303972, 损失为：0.235974
# 第56次模型优化后的参数权重：0.591142, 偏置为：0.308989, 损失为：0.247218
# 第57次模型优化后的参数权重：0.592142, 偏置为：0.313896, 损失为：0.237431
# 第58次模型优化后的参数权重：0.593014, 偏置为：0.318779, 损失为：0.246866
# 第59次模型优化后的参数权重：0.594473, 偏置为：0.323683, 损失为：0.245158
# 第60次模型优化后的参数权重：0.595285, 偏置为：0.328441, 损失为：0.228694
# 第61次模型优化后的参数权重：0.596890, 偏置为：0.333251, 损失为：0.224304
# 第62次模型优化后的参数权重：0.598161, 偏置为：0.338003, 损失为：0.221242
# 第63次模型优化后的参数权重：0.599501, 偏置为：0.342695, 损失为：0.195331
# 第64次模型优化后的参数权重：0.600456, 偏置为：0.347220, 损失为：0.218819
# 第65次模型优化后的参数权重：0.601348, 偏置为：0.351750, 损失为：0.203454
# 第66次模型优化后的参数权重：0.602804, 偏置为：0.356330, 损失为：0.212231
# 第67次模型优化后的参数权重：0.603779, 偏置为：0.360779, 损失为：0.199682
# 第68次模型优化后的参数权重：0.604677, 偏置为：0.365199, 损失为：0.194730
# 第69次模型优化后的参数权重：0.606387, 偏置为：0.369731, 损失为：0.182609
# 第70次模型优化后的参数权重：0.607583, 偏置为：0.374113, 损失为：0.184634
# 第71次模型优化后的参数权重：0.608822, 偏置为：0.378402, 损失为：0.178060
# 第72次模型优化后的参数权重：0.609622, 偏置为：0.382616, 损失为：0.202526
# 第73次模型优化后的参数权重：0.610432, 偏置为：0.386776, 损失为：0.183964
# 第74次模型优化后的参数权重：0.611387, 偏置为：0.390933, 损失为：0.172496
# 第75次模型优化后的参数权重：0.611936, 偏置为：0.394976, 损失为：0.170685
# 第76次模型优化后的参数权重：0.612231, 偏置为：0.398910, 损失为：0.165973
# 第77次模型优化后的参数权重：0.612522, 偏置为：0.402806, 损失为：0.166019
# 第78次模型优化后的参数权重：0.613204, 偏置为：0.406716, 损失为：0.163038
# 第79次模型优化后的参数权重：0.614471, 偏置为：0.410694, 损失为：0.164008
# 第80次模型优化后的参数权重：0.615695, 偏置为：0.414676, 损失为：0.154350
# 第81次模型优化后的参数权重：0.616271, 偏置为：0.418460, 损失为：0.149442
# 第82次模型优化后的参数权重：0.617397, 偏置为：0.422338, 损失为：0.144240
# 第83次模型优化后的参数权重：0.617853, 偏置为：0.426036, 损失为：0.139874
# 第84次模型优化后的参数权重：0.618979, 偏置为：0.429850, 损失为：0.149305
# 第85次模型优化后的参数权重：0.619710, 偏置为：0.433555, 损失为：0.140718
# 第86次模型优化后的参数权重：0.620663, 偏置为：0.437237, 损失为：0.142559
# 第87次模型优化后的参数权重：0.621232, 偏置为：0.440847, 损失为：0.122117
# 第88次模型优化后的参数权重：0.622321, 偏置为：0.444480, 损失为：0.128908
# 第89次模型优化后的参数权重：0.623565, 偏置为：0.448154, 损失为：0.116473
# 第90次模型优化后的参数权重：0.623711, 偏置为：0.451533, 损失为：0.125102
# 第91次模型优化后的参数权重：0.624497, 偏置为：0.455055, 损失为：0.136397
# 第92次模型优化后的参数权重：0.626076, 偏置为：0.458697, 损失为：0.122571
# 第93次模型优化后的参数权重：0.627326, 偏置为：0.462184, 损失为：0.122504
# 第94次模型优化后的参数权重：0.628188, 偏置为：0.465622, 损失为：0.119211
# 第95次模型优化后的参数权重：0.628931, 偏置为：0.468946, 损失为：0.116646
# 第96次模型优化后的参数权重：0.629654, 偏置为：0.472254, 损失为：0.107279
# 第97次模型优化后的参数权重：0.630964, 偏置为：0.475659, 损失为：0.113989
# 第98次模型优化后的参数权重：0.632198, 偏置为：0.479004, 损失为：0.102070
# 第99次模型优化后的参数权重：0.632943, 偏置为：0.482232, 损失为：0.107729
# 第100次模型优化后的参数权重：0.634415, 偏置为：0.485598, 损失为：0.104114
# 第101次模型优化后的参数权重：0.635221, 偏置为：0.488783, 损失为：0.101537
# 第102次模型优化后的参数权重：0.636268, 偏置为：0.491977, 损失为：0.096905
# 第103次模型优化后的参数权重：0.636471, 偏置为：0.494978, 损失为：0.101009
# 第104次模型优化后的参数权重：0.636649, 偏置为：0.497929, 损失为：0.102187
# 第105次模型优化后的参数权重：0.638034, 偏置为：0.501078, 损失为：0.092005
# 第106次模型优化后的参数权重：0.638144, 偏置为：0.503949, 损失为：0.090540
# 第107次模型优化后的参数权重：0.638737, 偏置为：0.506919, 损失为：0.088555
# 第108次模型优化后的参数权重：0.639386, 偏置为：0.509880, 损失为：0.085842
# 第109次模型优化后的参数权重：0.639483, 偏置为：0.512671, 损失为：0.082057
# 第110次模型优化后的参数权重：0.640062, 偏置为：0.515554, 损失为：0.077622
# 第111次模型优化后的参数权重：0.640992, 偏置为：0.518481, 损失为：0.081662
# 第112次模型优化后的参数权重：0.641910, 偏置为：0.521367, 损失为：0.083577
# 第113次模型优化后的参数权重：0.642531, 偏置为：0.524164, 损失为：0.083638
# 第114次模型优化后的参数权重：0.643815, 偏置为：0.527062, 损失为：0.078223
# 第115次模型优化后的参数权重：0.644413, 偏置为：0.529791, 损失为：0.074255
# 第116次模型优化后的参数权重：0.644778, 偏置为：0.532449, 损失为：0.075136
# 第117次模型优化后的参数权重：0.645102, 偏置为：0.535081, 损失为：0.073067
# 第118次模型优化后的参数权重：0.645803, 偏置为：0.537732, 损失为：0.074360
# 第119次模型优化后的参数权重：0.646185, 偏置为：0.540315, 损失为：0.072899
# 第120次模型优化后的参数权重：0.647282, 偏置为：0.543037, 损失为：0.069813
# 第121次模型优化后的参数权重：0.647452, 偏置为：0.545515, 损失为：0.063870
# 第122次模型优化后的参数权重：0.647776, 偏置为：0.548013, 损失为：0.061525
# 第123次模型优化后的参数权重：0.648311, 偏置为：0.550538, 损失为：0.067819
# 第124次模型优化后的参数权重：0.648952, 偏置为：0.553067, 损失为：0.066764
# 第125次模型优化后的参数权重：0.649226, 偏置为：0.555485, 损失为：0.064406
# 第126次模型优化后的参数权重：0.649395, 偏置为：0.557859, 损失为：0.062679
# 第127次模型优化后的参数权重：0.649960, 偏置为：0.560285, 损失为：0.057442
# 第128次模型优化后的参数权重：0.650093, 偏置为：0.562596, 损失为：0.057722
# 第129次模型优化后的参数权重：0.650886, 偏置为：0.565032, 损失为：0.059526
# 第130次模型优化后的参数权重：0.651353, 偏置为：0.567387, 损失为：0.056041
# 第131次模型优化后的参数权重：0.651898, 偏置为：0.569714, 损失为：0.054984
# 第132次模型优化后的参数权重：0.652306, 偏置为：0.571995, 损失为：0.054389
# 第133次模型优化后的参数权重：0.652549, 偏置为：0.574227, 损失为：0.052519
# 第134次模型优化后的参数权重：0.653227, 偏置为：0.576536, 损失为：0.051548
# 第135次模型优化后的参数权重：0.653012, 偏置为：0.578616, 损失为：0.050821
# 第136次模型优化后的参数权重：0.654058, 偏置为：0.580935, 损失为：0.052569
# 第137次模型优化后的参数权重：0.654396, 偏置为：0.583103, 损失为：0.049632
# 第138次模型优化后的参数权重：0.654951, 偏置为：0.585292, 损失为：0.047289
# 第139次模型优化后的参数权重：0.656091, 偏置为：0.587553, 损失为：0.046725
# 第140次模型优化后的参数权重：0.656346, 偏置为：0.589660, 损失为：0.049077
# 第141次模型优化后的参数权重：0.656430, 偏置为：0.591694, 损失为：0.044701
# 第142次模型优化后的参数权重：0.656898, 偏置为：0.593788, 损失为：0.043821
# 第143次模型优化后的参数权重：0.657223, 偏置为：0.595823, 损失为：0.041449
# 第144次模型优化后的参数权重：0.657638, 偏置为：0.597879, 损失为：0.041659
# 第145次模型优化后的参数权重：0.658069, 偏置为：0.599866, 损失为：0.042379
# 第146次模型优化后的参数权重：0.658428, 偏置为：0.601833, 损失为：0.040967
# 第147次模型优化后的参数权重：0.658820, 偏置为：0.603811, 损失为：0.041089
# 第148次模型优化后的参数权重：0.659464, 偏置为：0.605827, 损失为：0.040800
# 第149次模型优化后的参数权重：0.659872, 偏置为：0.607773, 损失为：0.038703
# 第150次模型优化后的参数权重：0.659875, 偏置为：0.609617, 损失为：0.037706
# 第151次模型优化后的参数权重：0.660096, 偏置为：0.611482, 损失为：0.040276
# 第152次模型优化后的参数权重：0.660327, 偏置为：0.613323, 损失为：0.035987
# 第153次模型优化后的参数权重：0.660646, 偏置为：0.615175, 损失为：0.035475
# 第154次模型优化后的参数权重：0.660904, 偏置为：0.616997, 损失为：0.034321
# 第155次模型优化后的参数权重：0.661223, 偏置为：0.618815, 损失为：0.036417
# 第156次模型优化后的参数权重：0.661485, 偏置为：0.620598, 损失为：0.034166
# 第157次模型优化后的参数权重：0.661750, 偏置为：0.622373, 损失为：0.033571
# 第158次模型优化后的参数权重：0.662128, 偏置为：0.624155, 损失为：0.032478
# 第159次模型优化后的参数权重：0.662715, 偏置为：0.625956, 损失为：0.031696
# 第160次模型优化后的参数权重：0.662997, 偏置为：0.627691, 损失为：0.031911
# 第161次模型优化后的参数权重：0.663293, 偏置为：0.629395, 损失为：0.031323
# 第162次模型优化后的参数权重：0.663672, 偏置为：0.631108, 损失为：0.029942
# 第163次模型优化后的参数权重：0.663831, 偏置为：0.632760, 损失为：0.029755
# 第164次模型优化后的参数权重：0.664146, 偏置为：0.634434, 损失为：0.029173
# 第165次模型优化后的参数权重：0.665015, 偏置为：0.636186, 损失为：0.028067
# 第166次模型优化后的参数权重：0.665486, 偏置为：0.637822, 损失为：0.026857
# 第167次模型优化后的参数权重：0.666100, 偏置为：0.639496, 损失为：0.025605
# 第168次模型优化后的参数权重：0.666687, 偏置为：0.641136, 损失为：0.025281
# 第169次模型优化后的参数权重：0.667083, 偏置为：0.642729, 损失为：0.024716
# 第170次模型优化后的参数权重：0.667719, 偏置为：0.644366, 损失为：0.024105
# 第171次模型优化后的参数权重：0.668014, 偏置为：0.645920, 损失为：0.025809
# 第172次模型优化后的参数权重：0.668581, 偏置为：0.647521, 损失为：0.025094
# 第173次模型优化后的参数权重：0.669034, 偏置为：0.649086, 损失为：0.022548
# 第174次模型优化后的参数权重：0.669476, 偏置为：0.650605, 损失为：0.023055
# 第175次模型优化后的参数权重：0.669987, 偏置为：0.652144, 损失为：0.023064
# 第176次模型优化后的参数权重：0.670470, 偏置为：0.653642, 损失为：0.023088
# 第177次模型优化后的参数权重：0.670645, 偏置为：0.655096, 损失为：0.020260
# 第178次模型优化后的参数权重：0.670996, 偏置为：0.656559, 损失为：0.021834
# 第179次模型优化后的参数权重：0.671008, 偏置为：0.657954, 损失为：0.022058
# 第180次模型优化后的参数权重：0.671168, 偏置为：0.659349, 损失为：0.019519
# 第181次模型优化后的参数权重：0.671224, 偏置为：0.660714, 损失为：0.020246
# 第182次模型优化后的参数权重：0.671302, 偏置为：0.662070, 损失为：0.020059
# 第183次模型优化后的参数权重：0.671504, 偏置为：0.663433, 损失为：0.019619
# 第184次模型优化后的参数权重：0.671704, 偏置为：0.664784, 损失为：0.019840
# 第185次模型优化后的参数权重：0.672070, 偏置为：0.666146, 损失为：0.018737
# 第186次模型优化后的参数权重：0.672318, 偏置为：0.667473, 损失为：0.017857
# 第187次模型优化后的参数权重：0.672651, 偏置为：0.668812, 损失为：0.017104
# 第188次模型优化后的参数权重：0.672860, 偏置为：0.670112, 损失为：0.016741
# 第189次模型优化后的参数权重：0.673068, 偏置为：0.671407, 损失为：0.017267
# 第190次模型优化后的参数权重：0.673176, 偏置为：0.672657, 损失为：0.017240
# 第191次模型优化后的参数权重：0.673522, 偏置为：0.673945, 损失为：0.016914
# 第192次模型优化后的参数权重：0.673819, 偏置为：0.675224, 损失为：0.015168
# 第193次模型优化后的参数权重：0.673992, 偏置为：0.676465, 损失为：0.015863
# 第194次模型优化后的参数权重：0.674381, 偏置为：0.677710, 损失为：0.015697
# 第195次模型优化后的参数权重：0.674927, 偏置为：0.678986, 损失为：0.015515
# 第196次模型优化后的参数权重：0.675167, 偏置为：0.680189, 损失为：0.014853
# 第197次模型优化后的参数权重：0.675447, 偏置为：0.681387, 损失为：0.013623
# 第198次模型优化后的参数权重：0.675851, 偏置为：0.682598, 损失为：0.014861
# 第199次模型优化后的参数权重：0.676211, 偏置为：0.683800, 损失为：0.013808
# 第200次模型优化后的参数权重：0.676283, 偏置为：0.684939, 损失为：0.014650
# 第201次模型优化后的参数权重：0.676454, 偏置为：0.686080, 损失为：0.013961
# 第202次模型优化后的参数权重：0.676772, 偏置为：0.687236, 损失为：0.013423
# 第203次模型优化后的参数权重：0.676924, 偏置为：0.688357, 损失为：0.012648
# 第204次模型优化后的参数权重：0.677087, 偏置为：0.689459, 损失为：0.012809
# 第205次模型优化后的参数权重：0.677372, 偏置为：0.690569, 损失为：0.012478
# 第206次模型优化后的参数权重：0.677585, 偏置为：0.691655, 损失为：0.012391
# 第207次模型优化后的参数权重：0.677559, 偏置为：0.692685, 损失为：0.011533
# 第208次模型优化后的参数权重：0.677944, 偏置为：0.693789, 损失为：0.012063
# 第209次模型优化后的参数权重：0.678030, 偏置为：0.694825, 损失为：0.011533
# 第210次模型优化后的参数权重：0.678333, 偏置为：0.695880, 损失为：0.011587
# 第211次模型优化后的参数权重：0.678343, 偏置为：0.696879, 损失为：0.011101
# 第212次模型优化后的参数权重：0.678418, 偏置为：0.697862, 损失为：0.010617
# 第213次模型优化后的参数权重：0.678774, 偏置为：0.698906, 损失为：0.010601
# 第214次模型优化后的参数权重：0.678921, 偏置为：0.699915, 损失为：0.010661
# 第215次模型优化后的参数权重：0.679153, 偏置为：0.700923, 损失为：0.010770
# 第216次模型优化后的参数权重：0.679199, 偏置为：0.701881, 损失为：0.009788
# 第217次模型优化后的参数权重：0.679481, 偏置为：0.702884, 损失为：0.010775
# 第218次模型优化后的参数权重：0.679512, 偏置为：0.703818, 损失为：0.009525
# 第219次模型优化后的参数权重：0.679716, 偏置为：0.704776, 损失为：0.009544
# 第220次模型优化后的参数权重：0.679948, 偏置为：0.705731, 损失为：0.009812
# 第221次模型优化后的参数权重：0.680151, 偏置为：0.706681, 损失为：0.009230
# 第222次模型优化后的参数权重：0.680436, 偏置为：0.707631, 损失为：0.009016
# 第223次模型优化后的参数权重：0.680860, 偏置为：0.708606, 损失为：0.009186
# 第224次模型优化后的参数权重：0.681055, 偏置为：0.709517, 损失为：0.009081
# 第225次模型优化后的参数权重：0.680962, 偏置为：0.710366, 损失为：0.008031
# 第226次模型优化后的参数权重：0.681117, 偏置为：0.711251, 损失为：0.008048
# 第227次模型优化后的参数权重：0.681312, 偏置为：0.712137, 损失为：0.008202
# 第228次模型优化后的参数权重：0.681503, 偏置为：0.713019, 损失为：0.008201
# 第229次模型优化后的参数权重：0.681858, 偏置为：0.713927, 损失为：0.007697
# 第230次模型优化后的参数权重：0.682125, 偏置为：0.714805, 损失为：0.007817
# 第231次模型优化后的参数权重：0.682379, 偏置为：0.715670, 损失为：0.006769
# 第232次模型优化后的参数权重：0.682574, 偏置为：0.716509, 损失为：0.007143
# 第233次模型优化后的参数权重：0.682647, 偏置为：0.717329, 损失为：0.006754
# 第234次模型优化后的参数权重：0.682755, 偏置为：0.718135, 损失为：0.007244
# 第235次模型优化后的参数权重：0.682885, 偏置为：0.718950, 损失为：0.006302
# 第236次模型优化后的参数权重：0.683174, 偏置为：0.719775, 损失为：0.007346
# 第237次模型优化后的参数权重：0.683375, 偏置为：0.720574, 损失为：0.006054
# 第238次模型优化后的参数权重：0.683508, 偏置为：0.721358, 损失为：0.006557
# 第239次模型优化后的参数权重：0.683532, 偏置为：0.722113, 损失为：0.006140
# 第240次模型优化后的参数权重：0.683837, 偏置为：0.722916, 损失为：0.006039
# 第241次模型优化后的参数权重：0.684035, 偏置为：0.723698, 损失为：0.006415
# 第242次模型优化后的参数权重：0.684270, 偏置为：0.724470, 损失为：0.006413
# 第243次模型优化后的参数权重：0.684383, 偏置为：0.725218, 损失为：0.005631
# 第244次模型优化后的参数权重：0.684560, 偏置为：0.725973, 损失为：0.005909
# 第245次模型优化后的参数权重：0.684647, 偏置为：0.726705, 损失为：0.005517
# 第246次模型优化后的参数权重：0.684845, 偏置为：0.727443, 损失为：0.005184
# 第247次模型优化后的参数权重：0.684812, 偏置为：0.728132, 损失为：0.005566
# 第248次模型优化后的参数权重：0.685046, 偏置为：0.728872, 损失为：0.005525
# 第249次模型优化后的参数权重：0.685291, 偏置为：0.729599, 损失为：0.004739
# 第250次模型优化后的参数权重：0.685429, 偏置为：0.730304, 损失为：0.005477
# 第251次模型优化后的参数权重：0.685461, 偏置为：0.730977, 损失为：0.005160
# 第252次模型优化后的参数权重：0.685600, 偏置为：0.731672, 损失为：0.004949
# 第253次模型优化后的参数权重：0.685695, 偏置为：0.732342, 损失为：0.005015
# 第254次模型优化后的参数权重：0.685780, 偏置为：0.733001, 损失为：0.004516
# 第255次模型优化后的参数权重：0.685918, 偏置为：0.733674, 损失为：0.004542
# 第256次模型优化后的参数权重：0.686034, 偏置为：0.734334, 损失为：0.004589
# 第257次模型优化后的参数权重：0.686084, 偏置为：0.734976, 损失为：0.004353
# 第258次模型优化后的参数权重：0.686253, 偏置为：0.735627, 损失为：0.004268
# 第259次模型优化后的参数权重：0.686384, 偏置为：0.736270, 损失为：0.004176
# 第260次模型优化后的参数权重：0.686493, 偏置为：0.736895, 损失为：0.004329
# 第261次模型优化后的参数权重：0.686738, 偏置为：0.737549, 损失为：0.003981
# 第262次模型优化后的参数权重：0.686809, 偏置为：0.738156, 损失为：0.003904
# 第263次模型优化后的参数权重：0.686992, 偏置为：0.738791, 损失为：0.003917
# 第264次模型优化后的参数权重：0.687084, 偏置为：0.739388, 损失为：0.003838
# 第265次模型优化后的参数权重：0.687212, 偏置为：0.739991, 损失为：0.004118
# 第266次模型优化后的参数权重：0.687439, 偏置为：0.740614, 损失为：0.003778
# 第267次模型优化后的参数权重：0.687706, 偏置为：0.741241, 损失为：0.003780
# 第268次模型优化后的参数权重：0.687987, 偏置为：0.741858, 损失为：0.003639
# 第269次模型优化后的参数权重：0.688080, 偏置为：0.742437, 损失为：0.003537
# 第270次模型优化后的参数权重：0.688370, 偏置为：0.743046, 损失为：0.003323
# 第271次模型优化后的参数权重：0.688597, 偏置为：0.743632, 损失为：0.003498
# 第272次模型优化后的参数权重：0.688709, 偏置为：0.744196, 损失为：0.003055
# 第273次模型优化后的参数权重：0.688883, 偏置为：0.744769, 损失为：0.002937
# 第274次模型优化后的参数权重：0.688943, 偏置为：0.745312, 损失为：0.003158
# 第275次模型优化后的参数权重：0.689030, 偏置为：0.745855, 损失为：0.003042
# 第276次模型优化后的参数权重：0.689209, 偏置为：0.746409, 损失为：0.002934
# 第277次模型优化后的参数权重：0.689197, 偏置为：0.746922, 损失为：0.002870
# 第278次模型优化后的参数权重：0.689324, 偏置为：0.747455, 损失为：0.002836
# 第279次模型优化后的参数权重：0.689427, 偏置为：0.747976, 损失为：0.002844
# 第280次模型优化后的参数权重：0.689485, 偏置为：0.748486, 损失为：0.002787
# 第281次模型优化后的参数权重：0.689538, 偏置为：0.748993, 损失为：0.002657
# 第282次模型优化后的参数权重：0.689622, 偏置为：0.749499, 损失为：0.002602
# 第283次模型优化后的参数权重：0.689637, 偏置为：0.749983, 损失为：0.002802
# 第284次模型优化后的参数权重：0.689728, 偏置为：0.750478, 损失为：0.002435
# 第285次模型优化后的参数权重：0.689763, 偏置为：0.750961, 损失为：0.002597
# 第286次模型优化后的参数权重：0.689879, 偏置为：0.751453, 损失为：0.002394
# 第287次模型优化后的参数权重：0.689999, 偏置为：0.751938, 损失为：0.002448
# 第288次模型优化后的参数权重：0.690065, 偏置为：0.752412, 损失为：0.002295
# 第289次模型优化后的参数权重：0.690137, 偏置为：0.752885, 损失为：0.002218
# 第290次模型优化后的参数权重：0.690241, 偏置为：0.753361, 损失为：0.002185
# 第291次模型优化后的参数权重：0.690348, 偏置为：0.753829, 损失为：0.002219
# 第292次模型优化后的参数权重：0.690435, 偏置为：0.754286, 损失为：0.002111
# 第293次模型优化后的参数权重：0.690557, 偏置为：0.754746, 损失为：0.002131
# 第294次模型优化后的参数权重：0.690645, 偏置为：0.755195, 损失为：0.002137
# 第295次模型优化后的参数权重：0.690716, 偏置为：0.755638, 损失为：0.002044
# 第296次模型优化后的参数权重：0.690867, 偏置为：0.756090, 损失为：0.002040
# 第297次模型优化后的参数权重：0.690955, 偏置为：0.756529, 损失为：0.001771
# 第298次模型优化后的参数权重：0.691019, 偏置为：0.756961, 损失为：0.002013
# 第299次模型优化后的参数权重：0.691085, 偏置为：0.757381, 损失为：0.001763
# 第300次模型优化后的参数权重：0.691187, 偏置为：0.757809, 损失为：0.001914
# 第301次模型优化后的参数权重：0.691331, 偏置为：0.758243, 损失为：0.001921
# 第302次模型优化后的参数权重：0.691392, 偏置为：0.758656, 损失为：0.001738
# 第303次模型优化后的参数权重：0.691514, 偏置为：0.759074, 损失为：0.001692
# 第304次模型优化后的参数权重：0.691587, 偏置为：0.759483, 损失为：0.001696
# 第305次模型优化后的参数权重：0.691755, 偏置为：0.759901, 损失为：0.001616
# 第306次模型优化后的参数权重：0.691886, 偏置为：0.760314, 损失为：0.001601
# 第307次模型优化后的参数权重：0.691947, 偏置为：0.760709, 损失为：0.001618
# 第308次模型优化后的参数权重：0.691921, 偏置为：0.761083, 损失为：0.001665
# 第309次模型优化后的参数权重：0.691951, 偏置为：0.761456, 损失为：0.001663
# 第310次模型优化后的参数权重：0.692092, 偏置为：0.761851, 损失为：0.001522
# 第311次模型优化后的参数权重：0.692195, 偏置为：0.762233, 损失为：0.001563
# 第312次模型优化后的参数权重：0.692273, 偏置为：0.762613, 损失为：0.001411
# 第313次模型优化后的参数权重：0.692293, 偏置为：0.762973, 损失为：0.001434
# 第314次模型优化后的参数权重：0.692377, 偏置为：0.763343, 损失为：0.001372
# 第315次模型优化后的参数权重：0.692512, 偏置为：0.763723, 损失为：0.001324
# 第316次模型优化后的参数权重：0.692528, 偏置为：0.764074, 损失为：0.001314
# 第317次模型优化后的参数权重：0.692604, 偏置为：0.764432, 损失为：0.001293
# 第318次模型优化后的参数权重：0.692761, 偏置为：0.764798, 损失为：0.001248
# 第319次模型优化后的参数权重：0.692821, 偏置为：0.765147, 损失为：0.001274
# 第320次模型优化后的参数权重：0.692895, 偏置为：0.765497, 损失为：0.001200
# 第321次模型优化后的参数权重：0.692945, 偏置为：0.765839, 损失为：0.001143
# 第322次模型优化后的参数权重：0.693078, 偏置为：0.766192, 损失为：0.001193
# 第323次模型优化后的参数权重：0.693229, 偏置为：0.766547, 损失为：0.001249
# 第324次模型优化后的参数权重：0.693313, 偏置为：0.766884, 损失为：0.001086
# 第325次模型优化后的参数权重：0.693381, 偏置为：0.767217, 损失为：0.001067
# 第326次模型优化后的参数权重：0.693421, 偏置为：0.767542, 损失为：0.001053
# 第327次模型优化后的参数权重：0.693549, 偏置为：0.767880, 损失为：0.001046
# 第328次模型优化后的参数权重：0.693615, 偏置为：0.768201, 损失为：0.001065
# 第329次模型优化后的参数权重：0.693673, 偏置为：0.768517, 损失为：0.001038
# 第330次模型优化后的参数权重：0.693680, 偏置为：0.768821, 损失为：0.000949
# 第331次模型优化后的参数权重：0.693787, 偏置为：0.769143, 损失为：0.000947
# 第332次模型优化后的参数权重：0.693915, 偏置为：0.769465, 损失为：0.000974
# 第333次模型优化后的参数权重：0.693990, 偏置为：0.769773, 损失为：0.001042
# 第334次模型优化后的参数权重：0.694030, 偏置为：0.770072, 损失为：0.000888
# 第335次模型优化后的参数权重：0.694095, 偏置为：0.770376, 损失为：0.000864
# 第336次模型优化后的参数权重：0.694129, 偏置为：0.770666, 损失为：0.000918
# 第337次模型优化后的参数权重：0.694263, 偏置为：0.770972, 损失为：0.000832
# 第338次模型优化后的参数权重：0.694307, 偏置为：0.771260, 损失为：0.000873
# 第339次模型优化后的参数权重：0.694322, 偏置为：0.771538, 损失为：0.000842
# 第340次模型优化后的参数权重：0.694413, 偏置为：0.771830, 损失为：0.000846
# 第341次模型优化后的参数权重：0.694485, 偏置为：0.772115, 损失为：0.000840
# 第342次模型优化后的参数权重：0.694540, 偏置为：0.772395, 损失为：0.000768
# 第343次模型优化后的参数权重：0.694579, 偏置为：0.772667, 损失为：0.000819
# 第344次模型优化后的参数权重：0.694638, 偏置为：0.772940, 损失为：0.000739
# 第345次模型优化后的参数权重：0.694676, 偏置为：0.773207, 损失为：0.000754
# 第346次模型优化后的参数权重：0.694754, 偏置为：0.773481, 损失为：0.000762
# 第347次模型优化后的参数权重：0.694789, 偏置为：0.773743, 损失为：0.000714
# 第348次模型优化后的参数权重：0.694851, 偏置为：0.774007, 损失为：0.000718
# 第349次模型优化后的参数权重：0.694946, 偏置为：0.774272, 损失为：0.000631
# 第350次模型优化后的参数权重：0.695052, 偏置为：0.774538, 损失为：0.000693
# 第351次模型优化后的参数权重：0.695111, 偏置为：0.774795, 损失为：0.000666
# 第352次模型优化后的参数权重：0.695147, 偏置为：0.775044, 损失为：0.000619
# 第353次模型优化后的参数权重：0.695182, 偏置为：0.775293, 损失为：0.000629
# 第354次模型优化后的参数权重：0.695214, 偏置为：0.775536, 损失为：0.000608
# 第355次模型优化后的参数权重：0.695246, 偏置为：0.775780, 损失为：0.000620
# 第356次模型优化后的参数权重：0.695274, 偏置为：0.776018, 损失为：0.000585
# 第357次模型优化后的参数权重：0.695338, 偏置为：0.776260, 损失为：0.000577
# 第358次模型优化后的参数权重：0.695367, 偏置为：0.776497, 损失为：0.000556
# 第359次模型优化后的参数权重：0.695420, 偏置为：0.776733, 损失为：0.000554
# 第360次模型优化后的参数权重：0.695471, 偏置为：0.776969, 损失为：0.000509
# 第361次模型优化后的参数权重：0.695508, 偏置为：0.777198, 损失为：0.000543
# 第362次模型优化后的参数权重：0.695564, 偏置为：0.777429, 损失为：0.000557
# 第363次模型优化后的参数权重：0.695590, 偏置为：0.777650, 损失为：0.000491
# 第364次模型优化后的参数权重：0.695617, 偏置为：0.777871, 损失为：0.000509
# 第365次模型优化后的参数权重：0.695611, 偏置为：0.778081, 损失为：0.000494
# 第366次模型优化后的参数权重：0.695616, 偏置为：0.778294, 损失为：0.000473
# 第367次模型优化后的参数权重：0.695639, 偏置为：0.778507, 损失为：0.000469
# 第368次模型优化后的参数权重：0.695697, 偏置为：0.778726, 损失为：0.000463
# 第369次模型优化后的参数权重：0.695711, 偏置为：0.778933, 损失为：0.000474
# 第370次模型优化后的参数权重：0.695730, 偏置为：0.779140, 损失为：0.000480
# 第371次模型优化后的参数权重：0.695776, 偏置为：0.779348, 损失为：0.000429
# 第372次模型优化后的参数权重：0.695824, 偏置为：0.779553, 损失为：0.000444
# 第373次模型优化后的参数权重：0.695861, 偏置为：0.779757, 损失为：0.000411
# 第374次模型优化后的参数权重：0.695906, 偏置为：0.779960, 损失为：0.000388
# 第375次模型优化后的参数权重：0.695964, 偏置为：0.780162, 损失为：0.000423
# 第376次模型优化后的参数权重：0.696007, 偏置为：0.780359, 损失为：0.000415
# 第377次模型优化后的参数权重：0.696032, 偏置为：0.780553, 损失为：0.000386
# 第378次模型优化后的参数权重：0.696078, 偏置为：0.780750, 损失为：0.000417
# 第379次模型优化后的参数权重：0.696130, 偏置为：0.780946, 损失为：0.000385
# 第380次模型优化后的参数权重：0.696186, 偏置为：0.781140, 损失为：0.000380
# 第381次模型优化后的参数权重：0.696221, 偏置为：0.781328, 损失为：0.000358
# 第382次模型优化后的参数权重：0.696272, 偏置为：0.781518, 损失为：0.000348
# 第383次模型优化后的参数权重：0.696317, 偏置为：0.781704, 损失为：0.000365
# 第384次模型优化后的参数权重：0.696349, 偏置为：0.781885, 损失为：0.000334
# 第385次模型优化后的参数权重：0.696368, 偏置为：0.782065, 损失为：0.000344
# 第386次模型优化后的参数权重：0.696394, 偏置为：0.782241, 损失为：0.000332
# 第387次模型优化后的参数权重：0.696419, 偏置为：0.782417, 损失为：0.000325
# 第388次模型优化后的参数权重：0.696449, 偏置为：0.782591, 损失为：0.000337
# 第389次模型优化后的参数权重：0.696513, 偏置为：0.782769, 损失为：0.000321
# 第390次模型优化后的参数权重：0.696579, 偏置为：0.782947, 损失为：0.000288
# 第391次模型优化后的参数权重：0.696603, 偏置为：0.783114, 损失为：0.000292
# 第392次模型优化后的参数权重：0.696620, 偏置为：0.783280, 损失为：0.000305
# 第393次模型优化后的参数权重：0.696640, 偏置为：0.783445, 损失为：0.000288
# 第394次模型优化后的参数权重：0.696675, 偏置为：0.783612, 损失为：0.000280
# 第395次模型优化后的参数权重：0.696702, 偏置为：0.783774, 损失为：0.000278
# 第396次模型优化后的参数权重：0.696723, 偏置为：0.783935, 损失为：0.000271
# 第397次模型优化后的参数权重：0.696783, 偏置为：0.784100, 损失为：0.000264
# 第398次模型优化后的参数权重：0.696855, 偏置为：0.784266, 损失为：0.000263
# 第399次模型优化后的参数权重：0.696895, 偏置为：0.784425, 损失为：0.000245
# 第400次模型优化后的参数权重：0.696953, 偏置为：0.784586, 损失为：0.000236
# 第401次模型优化后的参数权重：0.696977, 偏置为：0.784739, 损失为：0.000236
# 第402次模型优化后的参数权重：0.697013, 偏置为：0.784892, 损失为：0.000245
# 第403次模型优化后的参数权重：0.697013, 偏置为：0.785038, 损失为：0.000218
# 第404次模型优化后的参数权重：0.697043, 偏置为：0.785188, 损失为：0.000225
# 第405次模型优化后的参数权重：0.697073, 偏置为：0.785337, 损失为：0.000216
# 第406次模型优化后的参数权重：0.697111, 偏置为：0.785483, 损失为：0.000223
# 第407次模型优化后的参数权重：0.697125, 偏置为：0.785625, 损失为：0.000213
# 第408次模型优化后的参数权重：0.697158, 偏置为：0.785769, 损失为：0.000210
# 第409次模型优化后的参数权重：0.697206, 偏置为：0.785915, 损失为：0.000205
# 第410次模型优化后的参数权重：0.697235, 偏置为：0.786056, 损失为：0.000203
# 第411次模型优化后的参数权重：0.697274, 偏置为：0.786198, 损失为：0.000202
# 第412次模型优化后的参数权重：0.697298, 偏置为：0.786335, 损失为：0.000182
# 第413次模型优化后的参数权重：0.697318, 偏置为：0.786470, 损失为：0.000195
# 第414次模型优化后的参数权重：0.697373, 偏置为：0.786611, 损失为：0.000191
# 第415次模型优化后的参数权重：0.697415, 偏置为：0.786747, 损失为：0.000182
# 第416次模型优化后的参数权重：0.697440, 偏置为：0.786881, 损失为：0.000179
# 第417次模型优化后的参数权重：0.697469, 偏置为：0.787012, 损失为：0.000177
# 第418次模型优化后的参数权重：0.697483, 偏置为：0.787140, 损失为：0.000166
# 第419次模型优化后的参数权重：0.697489, 偏置为：0.787264, 损失为：0.000168
# 第420次模型优化后的参数权重：0.697513, 偏置为：0.787390, 损失为：0.000166
# 第421次模型优化后的参数权重：0.697553, 偏置为：0.787520, 损失为：0.000164
# 第422次模型优化后的参数权重：0.697592, 偏置为：0.787646, 损失为：0.000168
# 第423次模型优化后的参数权重：0.697614, 偏置为：0.787769, 损失为：0.000153
# 第424次模型优化后的参数权重：0.697623, 偏置为：0.787889, 损失为：0.000149
# 第425次模型优化后的参数权重：0.697655, 偏置为：0.788013, 损失为：0.000142
# 第426次模型优化后的参数权重：0.697695, 偏置为：0.788135, 损失为：0.000145
# 第427次模型优化后的参数权重：0.697705, 偏置为：0.788252, 损失为：0.000155
# 第428次模型优化后的参数权重：0.697713, 偏置为：0.788368, 损失为：0.000136
# 第429次模型优化后的参数权重：0.697757, 偏置为：0.788487, 损失为：0.000132
# 第430次模型优化后的参数权重：0.697773, 偏置为：0.788602, 损失为：0.000139
# 第431次模型优化后的参数权重：0.697795, 偏置为：0.788715, 损失为：0.000133
# 第432次模型优化后的参数权重：0.697824, 偏置为：0.788830, 损失为：0.000129
# 第433次模型优化后的参数权重：0.697835, 偏置为：0.788940, 损失为：0.000122
# 第434次模型优化后的参数权重：0.697879, 偏置为：0.789056, 损失为：0.000122
# 第435次模型优化后的参数权重：0.697910, 偏置为：0.789166, 损失为：0.000128
# 第436次模型优化后的参数权重：0.697931, 偏置为：0.789275, 损失为：0.000122
# 第437次模型优化后的参数权重：0.697933, 偏置为：0.789378, 损失为：0.000119
# 第438次模型优化后的参数权重：0.697970, 偏置为：0.789487, 损失为：0.000118
# 第439次模型优化后的参数权重：0.697994, 偏置为：0.789593, 损失为：0.000111
# 第440次模型优化后的参数权重：0.698000, 偏置为：0.789695, 损失为：0.000107
# 第441次模型优化后的参数权重：0.698018, 偏置为：0.789797, 损失为：0.000104
# 第442次模型优化后的参数权重：0.698018, 偏置为：0.789896, 损失为：0.000102
# 第443次模型优化后的参数权重：0.698030, 偏置为：0.789995, 损失为：0.000107
# 第444次模型优化后的参数权重：0.698041, 偏置为：0.790094, 损失为：0.000103
# 第445次模型优化后的参数权重：0.698061, 偏置为：0.790193, 损失为：0.000104
# 第446次模型优化后的参数权重：0.698087, 偏置为：0.790292, 损失为：0.000097
# 第447次模型优化后的参数权重：0.698124, 偏置为：0.790392, 损失为：0.000093
# 第448次模型优化后的参数权重：0.698143, 偏置为：0.790488, 损失为：0.000092
# 第449次模型优化后的参数权重：0.698154, 偏置为：0.790581, 损失为：0.000096
# 第450次模型优化后的参数权重：0.698171, 偏置为：0.790675, 损失为：0.000088
# 第451次模型优化后的参数权重：0.698197, 偏置为：0.790769, 损失为：0.000084
# 第452次模型优化后的参数权重：0.698216, 偏置为：0.790861, 损失为：0.000093
# 第453次模型优化后的参数权重：0.698260, 偏置为：0.790957, 损失为：0.000087
# 第454次模型优化后的参数权重：0.698258, 偏置为：0.791043, 损失为：0.000079
# 第455次模型优化后的参数权重：0.698283, 偏置为：0.791134, 损失为：0.000077
# 第456次模型优化后的参数权重：0.698309, 偏置为：0.791224, 损失为：0.000081
# 第457次模型优化后的参数权重：0.698332, 偏置为：0.791314, 损失为：0.000078
# 第458次模型优化后的参数权重：0.698353, 偏置为：0.791402, 损失为：0.000080
# 第459次模型优化后的参数权重：0.698382, 偏置为：0.791490, 损失为：0.000077
# 第460次模型优化后的参数权重：0.698400, 偏置为：0.791576, 损失为：0.000073
# 第461次模型优化后的参数权重：0.698420, 偏置为：0.791660, 损失为：0.000072
# 第462次模型优化后的参数权重：0.698459, 偏置为：0.791748, 损失为：0.000072
# 第463次模型优化后的参数权重：0.698478, 偏置为：0.791831, 损失为：0.000066
# 第464次模型优化后的参数权重：0.698485, 偏置为：0.791912, 损失为：0.000068
# 第465次模型优化后的参数权重：0.698491, 偏置为：0.791991, 损失为：0.000064
# 第466次模型优化后的参数权重：0.698514, 偏置为：0.792073, 损失为：0.000066
# 第467次模型优化后的参数权重：0.698540, 偏置为：0.792154, 损失为：0.000064
# 第468次模型优化后的参数权重：0.698551, 偏置为：0.792231, 损失为：0.000068
# 第469次模型优化后的参数权重：0.698568, 偏置为：0.792309, 损失为：0.000061
# 第470次模型优化后的参数权重：0.698587, 偏置为：0.792387, 损失为：0.000058
# 第471次模型优化后的参数权重：0.698601, 偏置为：0.792463, 损失为：0.000061
# 第472次模型优化后的参数权重：0.698619, 偏置为：0.792539, 损失为：0.000057
# 第473次模型优化后的参数权重：0.698637, 偏置为：0.792615, 损失为：0.000056
# 第474次模型优化后的参数权重：0.698673, 偏置为：0.792692, 损失为：0.000055
# 第475次模型优化后的参数权重：0.698686, 偏置为：0.792766, 损失为：0.000050
# 第476次模型优化后的参数权重：0.698700, 偏置为：0.792838, 损失为：0.000053
# 第477次模型优化后的参数权重：0.698712, 偏置为：0.792910, 损失为：0.000053
# 第478次模型优化后的参数权重：0.698731, 偏置为：0.792982, 损失为：0.000050
# 第479次模型优化后的参数权重：0.698744, 偏置为：0.793052, 损失为：0.000050
# 第480次模型优化后的参数权重：0.698750, 偏置为：0.793121, 损失为：0.000048
# 第481次模型优化后的参数权重：0.698772, 偏置为：0.793191, 损失为：0.000048
# 第482次模型优化后的参数权重：0.698784, 偏置为：0.793259, 损失为：0.000046
# 第483次模型优化后的参数权重：0.698783, 偏置为：0.793325, 损失为：0.000047
# 第484次模型优化后的参数权重：0.698791, 偏置为：0.793391, 损失为：0.000044
# 第485次模型优化后的参数权重：0.698804, 偏置为：0.793457, 损失为：0.000044
# 第486次模型优化后的参数权重：0.698826, 偏置为：0.793524, 损失为：0.000040
# 第487次模型优化后的参数权重：0.698831, 偏置为：0.793588, 损失为：0.000045
# 第488次模型优化后的参数权重：0.698849, 偏置为：0.793654, 损失为：0.000039
# 第489次模型优化后的参数权重：0.698863, 偏置为：0.793718, 损失为：0.000043
# 第490次模型优化后的参数权重：0.698879, 偏置为：0.793782, 损失为：0.000039
# 第491次模型优化后的参数权重：0.698882, 偏置为：0.793843, 损失为：0.000041
# 第492次模型优化后的参数权重：0.698893, 偏置为：0.793904, 损失为：0.000037
# 第493次模型优化后的参数权重：0.698902, 偏置为：0.793965, 损失为：0.000037
# 第494次模型优化后的参数权重：0.698928, 偏置为：0.794028, 损失为：0.000035
# 第495次模型优化后的参数权重：0.698938, 偏置为：0.794087, 损失为：0.000033
# 第496次模型优化后的参数权重：0.698944, 偏置为：0.794146, 损失为：0.000035
# 第497次模型优化后的参数权重：0.698950, 偏置为：0.794204, 损失为：0.000035
# 第498次模型优化后的参数权重：0.698964, 偏置为：0.794262, 损失为：0.000034
# 第499次模型优化后的参数权重：0.698973, 偏置为：0.794319, 损失为：0.000035
# 第500次模型优化后的参数权重：0.698977, 偏置为：0.794375, 损失为：0.000031
# 第501次模型优化后的参数权重：0.698985, 偏置为：0.794432, 损失为：0.000033
# 第502次模型优化后的参数权重：0.698997, 偏置为：0.794487, 损失为：0.000031
# 第503次模型优化后的参数权重：0.699012, 偏置为：0.794543, 损失为：0.000031
# 第504次模型优化后的参数权重：0.699022, 偏置为：0.794598, 损失为：0.000030
# 第505次模型优化后的参数权重：0.699028, 偏置为：0.794652, 损失为：0.000029
# 第506次模型优化后的参数权重：0.699033, 偏置为：0.794705, 损失为：0.000026
# 第507次模型优化后的参数权重：0.699043, 偏置为：0.794758, 损失为：0.000028
# 第508次模型优化后的参数权重：0.699058, 偏置为：0.794811, 损失为：0.000027
# 第509次模型优化后的参数权重：0.699068, 偏置为：0.794863, 损失为：0.000026
# 第510次模型优化后的参数权重：0.699084, 偏置为：0.794916, 损失为：0.000027
# 第511次模型优化后的参数权重：0.699099, 偏置为：0.794968, 损失为：0.000027
# 第512次模型优化后的参数权重：0.699102, 偏置为：0.795017, 损失为：0.000025
# 第513次模型优化后的参数权重：0.699117, 偏置为：0.795068, 损失为：0.000028
# 第514次模型优化后的参数权重：0.699132, 偏置为：0.795118, 损失为：0.000024
# 第515次模型优化后的参数权重：0.699139, 偏置为：0.795167, 损失为：0.000024
# 第516次模型优化后的参数权重：0.699149, 偏置为：0.795215, 损失为：0.000023
# 第517次模型优化后的参数权重：0.699161, 偏置为：0.795263, 损失为：0.000022
# 第518次模型优化后的参数权重：0.699166, 偏置为：0.795310, 损失为：0.000023
# 第519次模型优化后的参数权重：0.699184, 偏置为：0.795359, 损失为：0.000022
# 第520次模型优化后的参数权重：0.699197, 偏置为：0.795406, 损失为：0.000021
# 第521次模型优化后的参数权重：0.699205, 偏置为：0.795452, 损失为：0.000022
# 第522次模型优化后的参数权重：0.699211, 偏置为：0.795498, 损失为：0.000020
# 第523次模型优化后的参数权重：0.699227, 偏置为：0.795544, 损失为：0.000020
# 第524次模型优化后的参数权重：0.699233, 偏置为：0.795588, 损失为：0.000020
# 第525次模型优化后的参数权重：0.699246, 偏置为：0.795633, 损失为：0.000019
# 第526次模型优化后的参数权重：0.699259, 偏置为：0.795678, 损失为：0.000018
# 第527次模型优化后的参数权重：0.699267, 偏置为：0.795721, 损失为：0.000020
# 第528次模型优化后的参数权重：0.699269, 偏置为：0.795764, 损失为：0.000019
# 第529次模型优化后的参数权重：0.699280, 偏置为：0.795807, 损失为：0.000018
# 第530次模型优化后的参数权重：0.699292, 偏置为：0.795849, 损失为：0.000018
# 第531次模型优化后的参数权重：0.699299, 偏置为：0.795891, 损失为：0.000018
# 第532次模型优化后的参数权重：0.699307, 偏置为：0.795932, 损失为：0.000017
# 第533次模型优化后的参数权重：0.699312, 偏置为：0.795972, 损失为：0.000016
# 第534次模型优化后的参数权重：0.699320, 偏置为：0.796013, 损失为：0.000016
# 第535次模型优化后的参数权重：0.699330, 偏置为：0.796053, 损失为：0.000016
# 第536次模型优化后的参数权重：0.699338, 偏置为：0.796093, 损失为：0.000017
# 第537次模型优化后的参数权重：0.699345, 偏置为：0.796132, 损失为：0.000016
# 第538次模型优化后的参数权重：0.699348, 偏置为：0.796170, 损失为：0.000015
# 第539次模型优化后的参数权重：0.699355, 偏置为：0.796208, 损失为：0.000015
# 第540次模型优化后的参数权重：0.699358, 偏置为：0.796246, 损失为：0.000014
# 第541次模型优化后的参数权重：0.699359, 偏置为：0.796283, 损失为：0.000015
# 第542次模型优化后的参数权重：0.699362, 偏置为：0.796319, 损失为：0.000014
# 第543次模型优化后的参数权重：0.699370, 偏置为：0.796356, 损失为：0.000013
# 第544次模型优化后的参数权重：0.699375, 偏置为：0.796393, 损失为：0.000013
# 第545次模型优化后的参数权重：0.699381, 偏置为：0.796429, 损失为：0.000013
# 第546次模型优化后的参数权重：0.699391, 偏置为：0.796466, 损失为：0.000013
# 第547次模型优化后的参数权重：0.699394, 偏置为：0.796500, 损失为：0.000012
# 第548次模型优化后的参数权重：0.699397, 偏置为：0.796535, 损失为：0.000013
# 第549次模型优化后的参数权重：0.699402, 偏置为：0.796569, 损失为：0.000012
# 第550次模型优化后的参数权重：0.699413, 偏置为：0.796604, 损失为：0.000012
# 第551次模型优化后的参数权重：0.699421, 偏置为：0.796638, 损失为：0.000012
# 第552次模型优化后的参数权重：0.699428, 偏置为：0.796672, 损失为：0.000011
# 第553次模型优化后的参数权重：0.699436, 偏置为：0.796706, 损失为：0.000011
# 第554次模型优化后的参数权重：0.699438, 偏置为：0.796738, 损失为：0.000011
# 第555次模型优化后的参数权重：0.699441, 偏置为：0.796771, 损失为：0.000011
# 第556次模型优化后的参数权重：0.699449, 偏置为：0.796803, 损失为：0.000011
# 第557次模型优化后的参数权重：0.699455, 偏置为：0.796836, 损失为：0.000010
# 第558次模型优化后的参数权重：0.699463, 偏置为：0.796867, 损失为：0.000010
# 第559次模型优化后的参数权重：0.699467, 偏置为：0.796899, 损失为：0.000010
# 第560次模型优化后的参数权重：0.699473, 偏置为：0.796930, 损失为：0.000009
# 第561次模型优化后的参数权重：0.699480, 偏置为：0.796961, 损失为：0.000009
# 第562次模型优化后的参数权重：0.699487, 偏置为：0.796991, 损失为：0.000009
# 第563次模型优化后的参数权重：0.699494, 偏置为：0.797021, 损失为：0.000009
# 第564次模型优化后的参数权重：0.699503, 偏置为：0.797052, 损失为：0.000008
# 第565次模型优化后的参数权重：0.699507, 偏置为：0.797081, 损失为：0.000009
# 第566次模型优化后的参数权重：0.699520, 偏置为：0.797111, 损失为：0.000008
# 第567次模型优化后的参数权重：0.699527, 偏置为：0.797141, 损失为：0.000008
# 第568次模型优化后的参数权重：0.699532, 偏置为：0.797169, 损失为：0.000008
# 第569次模型优化后的参数权重：0.699536, 偏置为：0.797197, 损失为：0.000008
# 第570次模型优化后的参数权重：0.699539, 偏置为：0.797225, 损失为：0.000008
# 第571次模型优化后的参数权重：0.699542, 偏置为：0.797253, 损失为：0.000007
# 第572次模型优化后的参数权重：0.699544, 偏置为：0.797280, 损失为：0.000007
# 第573次模型优化后的参数权重：0.699550, 偏置为：0.797307, 损失为：0.000007
# 第574次模型优化后的参数权重：0.699555, 偏置为：0.797334, 损失为：0.000008
# 第575次模型优化后的参数权重：0.699557, 偏置为：0.797360, 损失为：0.000007
# 第576次模型优化后的参数权重：0.699560, 偏置为：0.797386, 损失为：0.000007
# 第577次模型优化后的参数权重：0.699569, 偏置为：0.797413, 损失为：0.000007
# 第578次模型优化后的参数权重：0.699576, 偏置为：0.797440, 损失为：0.000007
# 第579次模型优化后的参数权重：0.699579, 偏置为：0.797465, 损失为：0.000006
# 第580次模型优化后的参数权重：0.699580, 偏置为：0.797490, 损失为：0.000007
# 第581次模型优化后的参数权重：0.699585, 偏置为：0.797515, 损失为：0.000006
# 第582次模型优化后的参数权重：0.699589, 偏置为：0.797540, 损失为：0.000006
# 第583次模型优化后的参数权重：0.699590, 偏置为：0.797564, 损失为：0.000006
# 第584次模型优化后的参数权重：0.699597, 偏置为：0.797589, 损失为：0.000006
# 第585次模型优化后的参数权重：0.699603, 偏置为：0.797613, 损失为：0.000006
# 第586次模型优化后的参数权重：0.699609, 偏置为：0.797637, 损失为：0.000006
# 第587次模型优化后的参数权重：0.699616, 偏置为：0.797661, 损失为：0.000006
# 第588次模型优化后的参数权重：0.699618, 偏置为：0.797685, 损失为：0.000005
# 第589次模型优化后的参数权重：0.699622, 偏置为：0.797708, 损失为：0.000005
# 第590次模型优化后的参数权重：0.699626, 偏置为：0.797731, 损失为：0.000005
# 第591次模型优化后的参数权重：0.699629, 偏置为：0.797753, 损失为：0.000005
# 第592次模型优化后的参数权重：0.699632, 偏置为：0.797776, 损失为：0.000005
# 第593次模型优化后的参数权重：0.699634, 偏置为：0.797798, 损失为：0.000005
# 第594次模型优化后的参数权重：0.699637, 偏置为：0.797820, 损失为：0.000005
# 第595次模型优化后的参数权重：0.699642, 偏置为：0.797842, 损失为：0.000005
# 第596次模型优化后的参数权重：0.699645, 偏置为：0.797863, 损失为：0.000005
# 第597次模型优化后的参数权重：0.699652, 偏置为：0.797885, 损失为：0.000005
# 第598次模型优化后的参数权重：0.699655, 偏置为：0.797906, 损失为：0.000004
# 第599次模型优化后的参数权重：0.699655, 偏置为：0.797927, 损失为：0.000004
# 第600次模型优化后的参数权重：0.699659, 偏置为：0.797947, 损失为：0.000004
# 第601次模型优化后的参数权重：0.699661, 偏置为：0.797967, 损失为：0.000005
# 第602次模型优化后的参数权重：0.699667, 偏置为：0.797988, 损失为：0.000004
# 第603次模型优化后的参数权重：0.699671, 偏置为：0.798008, 损失为：0.000004
# 第604次模型优化后的参数权重：0.699675, 偏置为：0.798028, 损失为：0.000004
# 第605次模型优化后的参数权重：0.699678, 偏置为：0.798048, 损失为：0.000004
# 第606次模型优化后的参数权重：0.699680, 偏置为：0.798068, 损失为：0.000004
# 第607次模型优化后的参数权重：0.699683, 偏置为：0.798087, 损失为：0.000004
# 第608次模型优化后的参数权重：0.699685, 偏置为：0.798106, 损失为：0.000004
# 第609次模型优化后的参数权重：0.699692, 偏置为：0.798125, 损失为：0.000004
# 第610次模型优化后的参数权重：0.699697, 偏置为：0.798144, 损失为：0.000004
# 第611次模型优化后的参数权重：0.699699, 偏置为：0.798163, 损失为：0.000004
# 第612次模型优化后的参数权重：0.699703, 偏置为：0.798181, 损失为：0.000003
# 第613次模型优化后的参数权重：0.699704, 偏置为：0.798199, 损失为：0.000003
# 第614次模型优化后的参数权重：0.699705, 偏置为：0.798217, 损失为：0.000003
# 第615次模型优化后的参数权重：0.699707, 偏置为：0.798235, 损失为：0.000003
# 第616次模型优化后的参数权重：0.699709, 偏置为：0.798252, 损失为：0.000003
# 第617次模型优化后的参数权重：0.699714, 偏置为：0.798270, 损失为：0.000003
# 第618次模型优化后的参数权重：0.699718, 偏置为：0.798287, 损失为：0.000003
# 第619次模型优化后的参数权重：0.699722, 偏置为：0.798305, 损失为：0.000003
# 第620次模型优化后的参数权重：0.699725, 偏置为：0.798322, 损失为：0.000003
# 第621次模型优化后的参数权重：0.699726, 偏置为：0.798338, 损失为：0.000003
# 第622次模型优化后的参数权重：0.699732, 偏置为：0.798355, 损失为：0.000003
# 第623次模型优化后的参数权重：0.699733, 偏置为：0.798371, 损失为：0.000003
# 第624次模型优化后的参数权重：0.699735, 偏置为：0.798388, 损失为：0.000003
# 第625次模型优化后的参数权重：0.699737, 偏置为：0.798404, 损失为：0.000003
# 第626次模型优化后的参数权重：0.699737, 偏置为：0.798419, 损失为：0.000003
# 第627次模型优化后的参数权重：0.699740, 偏置为：0.798435, 损失为：0.000002
# 第628次模型优化后的参数权重：0.699744, 偏置为：0.798451, 损失为：0.000002
# 第629次模型优化后的参数权重：0.699747, 偏置为：0.798467, 损失为：0.000003
# 第630次模型优化后的参数权重：0.699750, 偏置为：0.798482, 损失为：0.000002
# 第631次模型优化后的参数权重：0.699753, 偏置为：0.798497, 损失为：0.000002
# 第632次模型优化后的参数权重：0.699755, 偏置为：0.798512, 损失为：0.000002
# 第633次模型优化后的参数权重：0.699759, 偏置为：0.798527, 损失为：0.000002
# 第634次模型优化后的参数权重：0.699762, 偏置为：0.798542, 损失为：0.000002
# 第635次模型优化后的参数权重：0.699764, 偏置为：0.798557, 损失为：0.000002
# 第636次模型优化后的参数权重：0.699765, 偏置为：0.798571, 损失为：0.000002
# 第637次模型优化后的参数权重：0.699768, 偏置为：0.798585, 损失为：0.000002
# 第638次模型优化后的参数权重：0.699770, 偏置为：0.798599, 损失为：0.000002
# 第639次模型优化后的参数权重：0.699772, 偏置为：0.798613, 损失为：0.000002
# 第640次模型优化后的参数权重：0.699777, 偏置为：0.798628, 损失为：0.000002
# 第641次模型优化后的参数权重：0.699780, 偏置为：0.798641, 损失为：0.000002
# 第642次模型优化后的参数权重：0.699782, 偏置为：0.798655, 损失为：0.000002
# 第643次模型优化后的参数权重：0.699783, 偏置为：0.798668, 损失为：0.000002
# 第644次模型优化后的参数权重：0.699789, 偏置为：0.798682, 损失为：0.000002
# 第645次模型优化后的参数权重：0.699793, 偏置为：0.798696, 损失为：0.000002
# 第646次模型优化后的参数权重：0.699797, 偏置为：0.798709, 损失为：0.000002
# 第647次模型优化后的参数权重：0.699798, 偏置为：0.798722, 损失为：0.000002
# 第648次模型优化后的参数权重：0.699797, 偏置为：0.798734, 损失为：0.000002
# 第649次模型优化后的参数权重：0.699796, 偏置为：0.798746, 损失为：0.000002
# 第650次模型优化后的参数权重：0.699799, 偏置为：0.798759, 损失为：0.000002
# 第651次模型优化后的参数权重：0.699800, 偏置为：0.798771, 损失为：0.000002
# 第652次模型优化后的参数权重：0.699800, 偏置为：0.798783, 损失为：0.000001
# 第653次模型优化后的参数权重：0.699803, 偏置为：0.798795, 损失为：0.000001
# 第654次模型优化后的参数权重：0.699804, 偏置为：0.798807, 损失为：0.000002
# 第655次模型优化后的参数权重：0.699805, 偏置为：0.798819, 损失为：0.000001
# 第656次模型优化后的参数权重：0.699807, 偏置为：0.798831, 损失为：0.000001
# 第657次模型优化后的参数权重：0.699807, 偏置为：0.798842, 损失为：0.000001
# 第658次模型优化后的参数权重：0.699809, 偏置为：0.798854, 损失为：0.000001
# 第659次模型优化后的参数权重：0.699811, 偏置为：0.798866, 损失为：0.000001
# 第660次模型优化后的参数权重：0.699813, 偏置为：0.798877, 损失为：0.000001
# 第661次模型优化后的参数权重：0.699815, 偏置为：0.798888, 损失为：0.000001
# 第662次模型优化后的参数权重：0.699816, 偏置为：0.798899, 损失为：0.000001
# 第663次模型优化后的参数权重：0.699817, 偏置为：0.798910, 损失为：0.000001
# 第664次模型优化后的参数权重：0.699818, 偏置为：0.798921, 损失为：0.000001
# 第665次模型优化后的参数权重：0.699819, 偏置为：0.798931, 损失为：0.000001
# 第666次模型优化后的参数权重：0.699822, 偏置为：0.798942, 损失为：0.000001
# 第667次模型优化后的参数权重：0.699826, 偏置为：0.798953, 损失为：0.000001
# 第668次模型优化后的参数权重：0.699827, 偏置为：0.798964, 损失为：0.000001
# 第669次模型优化后的参数权重：0.699829, 偏置为：0.798974, 损失为：0.000001
# 第670次模型优化后的参数权重：0.699831, 偏置为：0.798984, 损失为：0.000001
# 第671次模型优化后的参数权重：0.699832, 偏置为：0.798994, 损失为：0.000001
# 第672次模型优化后的参数权重：0.699834, 偏置为：0.799004, 损失为：0.000001
# 第673次模型优化后的参数权重：0.699837, 偏置为：0.799015, 损失为：0.000001
# 第674次模型优化后的参数权重：0.699837, 偏置为：0.799024, 损失为：0.000001
# 第675次模型优化后的参数权重：0.699838, 偏置为：0.799034, 损失为：0.000001
# 第676次模型优化后的参数权重：0.699840, 偏置为：0.799043, 损失为：0.000001
# 第677次模型优化后的参数权重：0.699840, 偏置为：0.799053, 损失为：0.000001
# 第678次模型优化后的参数权重：0.699843, 偏置为：0.799062, 损失为：0.000001
# 第679次模型优化后的参数权重：0.699843, 偏置为：0.799072, 损失为：0.000001
# 第680次模型优化后的参数权重：0.699845, 偏置为：0.799081, 损失为：0.000001
# 第681次模型优化后的参数权重：0.699846, 偏置为：0.799090, 损失为：0.000001
# 第682次模型优化后的参数权重：0.699849, 偏置为：0.799099, 损失为：0.000001
# 第683次模型优化后的参数权重：0.699853, 偏置为：0.799109, 损失为：0.000001
# 第684次模型优化后的参数权重：0.699853, 偏置为：0.799118, 损失为：0.000001
# 第685次模型优化后的参数权重：0.699852, 偏置为：0.799126, 损失为：0.000001
# 第686次模型优化后的参数权重：0.699854, 偏置为：0.799135, 损失为：0.000001
# 第687次模型优化后的参数权重：0.699855, 偏置为：0.799143, 损失为：0.000001
# 第688次模型优化后的参数权重：0.699856, 偏置为：0.799152, 损失为：0.000001
# 第689次模型优化后的参数权重：0.699858, 偏置为：0.799160, 损失为：0.000001
# 第690次模型优化后的参数权重：0.699860, 偏置为：0.799169, 损失为：0.000001
# 第691次模型优化后的参数权重：0.699861, 偏置为：0.799177, 损失为：0.000001
# 第692次模型优化后的参数权重：0.699862, 偏置为：0.799185, 损失为：0.000001
# 第693次模型优化后的参数权重：0.699863, 偏置为：0.799193, 损失为：0.000001
# 第694次模型优化后的参数权重：0.699864, 偏置为：0.799201, 损失为：0.000001
# 第695次模型优化后的参数权重：0.699866, 偏置为：0.799209, 损失为：0.000001
# 第696次模型优化后的参数权重：0.699868, 偏置为：0.799217, 损失为：0.000001
# 第697次模型优化后的参数权重：0.699870, 偏置为：0.799225, 损失为：0.000001
# 第698次模型优化后的参数权重：0.699870, 偏置为：0.799233, 损失为：0.000001
# 第699次模型优化后的参数权重：0.699871, 偏置为：0.799240, 损失为：0.000001
# 第700次模型优化后的参数权重：0.699872, 偏置为：0.799248, 损失为：0.000001
# 第701次模型优化后的参数权重：0.699874, 偏置为：0.799256, 损失为：0.000001
# 第702次模型优化后的参数权重：0.699874, 偏置为：0.799263, 损失为：0.000001
# 第703次模型优化后的参数权重：0.699876, 偏置为：0.799270, 损失为：0.000001
# 第704次模型优化后的参数权重：0.699878, 偏置为：0.799278, 损失为：0.000001
# 第705次模型优化后的参数权重：0.699880, 偏置为：0.799285, 损失为：0.000001
# 第706次模型优化后的参数权重：0.699881, 偏置为：0.799292, 损失为：0.000001
# 第707次模型优化后的参数权重：0.699881, 偏置为：0.799299, 损失为：0.000000
# 第708次模型优化后的参数权重：0.699883, 偏置为：0.799306, 损失为：0.000001
# 第709次模型优化后的参数权重：0.699885, 偏置为：0.799313, 损失为：0.000001
# 第710次模型优化后的参数权重：0.699886, 偏置为：0.799320, 损失为：0.000000
# 第711次模型优化后的参数权重：0.699889, 偏置为：0.799327, 损失为：0.000000
# 第712次模型优化后的参数权重：0.699890, 偏置为：0.799334, 损失为：0.000000
# 第713次模型优化后的参数权重：0.699890, 偏置为：0.799340, 损失为：0.000000
# 第714次模型优化后的参数权重：0.699891, 偏置为：0.799347, 损失为：0.000000
# 第715次模型优化后的参数权重：0.699892, 偏置为：0.799353, 损失为：0.000000
# 第716次模型优化后的参数权重：0.699891, 偏置为：0.799360, 损失为：0.000000
# 第717次模型优化后的参数权重：0.699893, 偏置为：0.799366, 损失为：0.000000
# 第718次模型优化后的参数权重：0.699894, 偏置为：0.799372, 损失为：0.000000
# 第719次模型优化后的参数权重：0.699896, 偏置为：0.799379, 损失为：0.000000
# 第720次模型优化后的参数权重：0.699897, 偏置为：0.799385, 损失为：0.000000
# 第721次模型优化后的参数权重：0.699898, 偏置为：0.799391, 损失为：0.000000
# 第722次模型优化后的参数权重：0.699899, 偏置为：0.799397, 损失为：0.000000
# 第723次模型优化后的参数权重：0.699901, 偏置为：0.799403, 损失为：0.000000
# 第724次模型优化后的参数权重：0.699902, 偏置为：0.799409, 损失为：0.000000
# 第725次模型优化后的参数权重：0.699903, 偏置为：0.799415, 损失为：0.000000
# 第726次模型优化后的参数权重：0.699903, 偏置为：0.799421, 损失为：0.000000
# 第727次模型优化后的参数权重：0.699904, 偏置为：0.799427, 损失为：0.000000
# 第728次模型优化后的参数权重：0.699905, 偏置为：0.799433, 损失为：0.000000
# 第729次模型优化后的参数权重：0.699906, 偏置为：0.799438, 损失为：0.000000
# 第730次模型优化后的参数权重：0.699906, 偏置为：0.799444, 损失为：0.000000
# 第731次模型优化后的参数权重：0.699908, 偏置为：0.799449, 损失为：0.000000
# 第732次模型优化后的参数权重：0.699909, 偏置为：0.799455, 损失为：0.000000
# 第733次模型优化后的参数权重：0.699911, 偏置为：0.799460, 损失为：0.000000
# 第734次模型优化后的参数权重：0.699911, 偏置为：0.799466, 损失为：0.000000
# 第735次模型优化后的参数权重：0.699912, 偏置为：0.799471, 损失为：0.000000
# 第736次模型优化后的参数权重：0.699913, 偏置为：0.799477, 损失为：0.000000
# 第737次模型优化后的参数权重：0.699914, 偏置为：0.799482, 损失为：0.000000
# 第738次模型优化后的参数权重：0.699915, 偏置为：0.799487, 损失为：0.000000
# 第739次模型优化后的参数权重：0.699916, 偏置为：0.799492, 损失为：0.000000
# 第740次模型优化后的参数权重：0.699917, 偏置为：0.799497, 损失为：0.000000
# 第741次模型优化后的参数权重：0.699919, 偏置为：0.799502, 损失为：0.000000
# 第742次模型优化后的参数权重：0.699919, 偏置为：0.799507, 损失为：0.000000
# 第743次模型优化后的参数权重：0.699920, 偏置为：0.799512, 损失为：0.000000
# 第744次模型优化后的参数权重：0.699920, 偏置为：0.799517, 损失为：0.000000
# 第745次模型优化后的参数权重：0.699920, 偏置为：0.799522, 损失为：0.000000
# 第746次模型优化后的参数权重：0.699921, 偏置为：0.799527, 损失为：0.000000
# 第747次模型优化后的参数权重：0.699921, 偏置为：0.799531, 损失为：0.000000
# 第748次模型优化后的参数权重：0.699922, 偏置为：0.799536, 损失为：0.000000
# 第749次模型优化后的参数权重：0.699923, 偏置为：0.799541, 损失为：0.000000
# 第750次模型优化后的参数权重：0.699924, 偏置为：0.799545, 损失为：0.000000
# 第751次模型优化后的参数权重：0.699924, 偏置为：0.799550, 损失为：0.000000
# 第752次模型优化后的参数权重：0.699925, 偏置为：0.799554, 损失为：0.000000
# 第753次模型优化后的参数权重：0.699926, 偏置为：0.799559, 损失为：0.000000
# 第754次模型优化后的参数权重：0.699927, 偏置为：0.799563, 损失为：0.000000
# 第755次模型优化后的参数权重：0.699928, 偏置为：0.799568, 损失为：0.000000
# 第756次模型优化后的参数权重：0.699928, 偏置为：0.799572, 损失为：0.000000
# 第757次模型优化后的参数权重：0.699928, 偏置为：0.799576, 损失为：0.000000
# 第758次模型优化后的参数权重：0.699929, 偏置为：0.799580, 损失为：0.000000
# 第759次模型优化后的参数权重：0.699929, 偏置为：0.799585, 损失为：0.000000
# 第760次模型优化后的参数权重：0.699931, 偏置为：0.799589, 损失为：0.000000
# 第761次模型优化后的参数权重：0.699931, 偏置为：0.799593, 损失为：0.000000
# 第762次模型优化后的参数权重：0.699932, 偏置为：0.799597, 损失为：0.000000
# 第763次模型优化后的参数权重：0.699932, 偏置为：0.799601, 损失为：0.000000
# 第764次模型优化后的参数权重：0.699932, 偏置为：0.799605, 损失为：0.000000
# 第765次模型优化后的参数权重：0.699934, 偏置为：0.799609, 损失为：0.000000
# 第766次模型优化后的参数权重：0.699934, 偏置为：0.799613, 损失为：0.000000
# 第767次模型优化后的参数权重：0.699934, 偏置为：0.799617, 损失为：0.000000
# 第768次模型优化后的参数权重：0.699935, 偏置为：0.799620, 损失为：0.000000
# 第769次模型优化后的参数权重：0.699936, 偏置为：0.799624, 损失为：0.000000
# 第770次模型优化后的参数权重：0.699936, 偏置为：0.799628, 损失为：0.000000
# 第771次模型优化后的参数权重：0.699937, 偏置为：0.799632, 损失为：0.000000
# 第772次模型优化后的参数权重：0.699938, 偏置为：0.799635, 损失为：0.000000
# 第773次模型优化后的参数权重：0.699938, 偏置为：0.799639, 损失为：0.000000
# 第774次模型优化后的参数权重：0.699938, 偏置为：0.799642, 损失为：0.000000
# 第775次模型优化后的参数权重：0.699939, 偏置为：0.799646, 损失为：0.000000
# 第776次模型优化后的参数权重：0.699939, 偏置为：0.799650, 损失为：0.000000
# 第777次模型优化后的参数权重：0.699940, 偏置为：0.799653, 损失为：0.000000
# 第778次模型优化后的参数权重：0.699941, 偏置为：0.799657, 损失为：0.000000
# 第779次模型优化后的参数权重：0.699942, 偏置为：0.799660, 损失为：0.000000
# 第780次模型优化后的参数权重：0.699942, 偏置为：0.799663, 损失为：0.000000
# 第781次模型优化后的参数权重：0.699943, 偏置为：0.799667, 损失为：0.000000
# 第782次模型优化后的参数权重：0.699943, 偏置为：0.799670, 损失为：0.000000
# 第783次模型优化后的参数权重：0.699944, 偏置为：0.799673, 损失为：0.000000
# 第784次模型优化后的参数权重：0.699945, 偏置为：0.799677, 损失为：0.000000
# 第785次模型优化后的参数权重：0.699945, 偏置为：0.799680, 损失为：0.000000
# 第786次模型优化后的参数权重：0.699946, 偏置为：0.799683, 损失为：0.000000
# 第787次模型优化后的参数权重：0.699946, 偏置为：0.799686, 损失为：0.000000
# 第788次模型优化后的参数权重：0.699947, 偏置为：0.799689, 损失为：0.000000
# 第789次模型优化后的参数权重：0.699947, 偏置为：0.799693, 损失为：0.000000
# 第790次模型优化后的参数权重：0.699948, 偏置为：0.799696, 损失为：0.000000
# 第791次模型优化后的参数权重：0.699948, 偏置为：0.799699, 损失为：0.000000
# 第792次模型优化后的参数权重：0.699948, 偏置为：0.799702, 损失为：0.000000
# 第793次模型优化后的参数权重：0.699949, 偏置为：0.799705, 损失为：0.000000
# 第794次模型优化后的参数权重：0.699950, 偏置为：0.799708, 损失为：0.000000
# 第795次模型优化后的参数权重：0.699950, 偏置为：0.799711, 损失为：0.000000
# 第796次模型优化后的参数权重：0.699951, 偏置为：0.799713, 损失为：0.000000
# 第797次模型优化后的参数权重：0.699951, 偏置为：0.799716, 损失为：0.000000
# 第798次模型优化后的参数权重：0.699951, 偏置为：0.799719, 损失为：0.000000
# 第799次模型优化后的参数权重：0.699952, 偏置为：0.799722, 损失为：0.000000
# 第800次模型优化后的参数权重：0.699952, 偏置为：0.799725, 损失为：0.000000
# 第801次模型优化后的参数权重：0.699953, 偏置为：0.799728, 损失为：0.000000
# 第802次模型优化后的参数权重：0.699953, 偏置为：0.799730, 损失为：0.000000
# 第803次模型优化后的参数权重：0.699954, 偏置为：0.799733, 损失为：0.000000
# 第804次模型优化后的参数权重：0.699954, 偏置为：0.799736, 损失为：0.000000
# 第805次模型优化后的参数权重：0.699954, 偏置为：0.799738, 损失为：0.000000
# 第806次模型优化后的参数权重：0.699955, 偏置为：0.799741, 损失为：0.000000
# 第807次模型优化后的参数权重：0.699955, 偏置为：0.799743, 损失为：0.000000
# 第808次模型优化后的参数权重：0.699956, 偏置为：0.799746, 损失为：0.000000
# 第809次模型优化后的参数权重：0.699956, 偏置为：0.799748, 损失为：0.000000
# 第810次模型优化后的参数权重：0.699956, 偏置为：0.799751, 损失为：0.000000
# 第811次模型优化后的参数权重：0.699956, 偏置为：0.799753, 损失为：0.000000
# 第812次模型优化后的参数权重：0.699957, 偏置为：0.799756, 损失为：0.000000
# 第813次模型优化后的参数权重：0.699958, 偏置为：0.799758, 损失为：0.000000
# 第814次模型优化后的参数权重：0.699958, 偏置为：0.799761, 损失为：0.000000
# 第815次模型优化后的参数权重：0.699959, 偏置为：0.799763, 损失为：0.000000
# 第816次模型优化后的参数权重：0.699959, 偏置为：0.799766, 损失为：0.000000
# 第817次模型优化后的参数权重：0.699960, 偏置为：0.799768, 损失为：0.000000
# 第818次模型优化后的参数权重：0.699960, 偏置为：0.799770, 损失为：0.000000
# 第819次模型优化后的参数权重：0.699960, 偏置为：0.799772, 损失为：0.000000
# 第820次模型优化后的参数权重：0.699961, 偏置为：0.799775, 损失为：0.000000
# 第821次模型优化后的参数权重：0.699961, 偏置为：0.799777, 损失为：0.000000
# 第822次模型优化后的参数权重：0.699961, 偏置为：0.799779, 损失为：0.000000
# 第823次模型优化后的参数权重：0.699962, 偏置为：0.799781, 损失为：0.000000
# 第824次模型优化后的参数权重：0.699962, 偏置为：0.799784, 损失为：0.000000
# 第825次模型优化后的参数权重：0.699962, 偏置为：0.799786, 损失为：0.000000
# 第826次模型优化后的参数权重：0.699963, 偏置为：0.799788, 损失为：0.000000
# 第827次模型优化后的参数权重：0.699963, 偏置为：0.799790, 损失为：0.000000
# 第828次模型优化后的参数权重：0.699963, 偏置为：0.799792, 损失为：0.000000
# 第829次模型优化后的参数权重：0.699964, 偏置为：0.799794, 损失为：0.000000
# 第830次模型优化后的参数权重：0.699964, 偏置为：0.799796, 损失为：0.000000
# 第831次模型优化后的参数权重：0.699964, 偏置为：0.799798, 损失为：0.000000
# 第832次模型优化后的参数权重：0.699964, 偏置为：0.799800, 损失为：0.000000
# 第833次模型优化后的参数权重：0.699964, 偏置为：0.799802, 损失为：0.000000
# 第834次模型优化后的参数权重：0.699965, 偏置为：0.799804, 损失为：0.000000
# 第835次模型优化后的参数权重：0.699965, 偏置为：0.799806, 损失为：0.000000
# 第836次模型优化后的参数权重：0.699966, 偏置为：0.799808, 损失为：0.000000
# 第837次模型优化后的参数权重：0.699966, 偏置为：0.799810, 损失为：0.000000
# 第838次模型优化后的参数权重：0.699967, 偏置为：0.799812, 损失为：0.000000
# 第839次模型优化后的参数权重：0.699967, 偏置为：0.799814, 损失为：0.000000
# 第840次模型优化后的参数权重：0.699967, 偏置为：0.799816, 损失为：0.000000
# 第841次模型优化后的参数权重：0.699968, 偏置为：0.799818, 损失为：0.000000
# 第842次模型优化后的参数权重：0.699968, 偏置为：0.799819, 损失为：0.000000
# 第843次模型优化后的参数权重：0.699968, 偏置为：0.799821, 损失为：0.000000
# 第844次模型优化后的参数权重：0.699969, 偏置为：0.799823, 损失为：0.000000
# 第845次模型优化后的参数权重：0.699969, 偏置为：0.799825, 损失为：0.000000
# 第846次模型优化后的参数权重：0.699969, 偏置为：0.799827, 损失为：0.000000
# 第847次模型优化后的参数权重：0.699970, 偏置为：0.799828, 损失为：0.000000
# 第848次模型优化后的参数权重：0.699970, 偏置为：0.799830, 损失为：0.000000
# 第849次模型优化后的参数权重：0.699970, 偏置为：0.799832, 损失为：0.000000
# 第850次模型优化后的参数权重：0.699970, 偏置为：0.799833, 损失为：0.000000
# 第851次模型优化后的参数权重：0.699970, 偏置为：0.799835, 损失为：0.000000
# 第852次模型优化后的参数权重：0.699971, 偏置为：0.799837, 损失为：0.000000
# 第853次模型优化后的参数权重：0.699971, 偏置为：0.799838, 损失为：0.000000
# 第854次模型优化后的参数权重：0.699972, 偏置为：0.799840, 损失为：0.000000
# 第855次模型优化后的参数权重：0.699972, 偏置为：0.799842, 损失为：0.000000
# 第856次模型优化后的参数权重：0.699972, 偏置为：0.799843, 损失为：0.000000
# 第857次模型优化后的参数权重：0.699972, 偏置为：0.799845, 损失为：0.000000
# 第858次模型优化后的参数权重：0.699973, 偏置为：0.799846, 损失为：0.000000
# 第859次模型优化后的参数权重：0.699973, 偏置为：0.799848, 损失为：0.000000
# 第860次模型优化后的参数权重：0.699973, 偏置为：0.799849, 损失为：0.000000
# 第861次模型优化后的参数权重：0.699974, 偏置为：0.799851, 损失为：0.000000
# 第862次模型优化后的参数权重：0.699974, 偏置为：0.799852, 损失为：0.000000
# 第863次模型优化后的参数权重：0.699974, 偏置为：0.799854, 损失为：0.000000
# 第864次模型优化后的参数权重：0.699974, 偏置为：0.799855, 损失为：0.000000
# 第865次模型优化后的参数权重：0.699974, 偏置为：0.799857, 损失为：0.000000
# 第866次模型优化后的参数权重：0.699975, 偏置为：0.799858, 损失为：0.000000
# 第867次模型优化后的参数权重：0.699975, 偏置为：0.799860, 损失为：0.000000
# 第868次模型优化后的参数权重：0.699975, 偏置为：0.799861, 损失为：0.000000
# 第869次模型优化后的参数权重：0.699976, 偏置为：0.799862, 损失为：0.000000
# 第870次模型优化后的参数权重：0.699976, 偏置为：0.799864, 损失为：0.000000
# 第871次模型优化后的参数权重：0.699976, 偏置为：0.799865, 损失为：0.000000
# 第872次模型优化后的参数权重：0.699977, 偏置为：0.799867, 损失为：0.000000
# 第873次模型优化后的参数权重：0.699977, 偏置为：0.799868, 损失为：0.000000
# 第874次模型优化后的参数权重：0.699977, 偏置为：0.799869, 损失为：0.000000
# 第875次模型优化后的参数权重：0.699977, 偏置为：0.799871, 损失为：0.000000
# 第876次模型优化后的参数权重：0.699978, 偏置为：0.799872, 损失为：0.000000
# 第877次模型优化后的参数权重：0.699978, 偏置为：0.799873, 损失为：0.000000
# 第878次模型优化后的参数权重：0.699978, 偏置为：0.799874, 损失为：0.000000
# 第879次模型优化后的参数权重：0.699979, 偏置为：0.799876, 损失为：0.000000
# 第880次模型优化后的参数权重：0.699979, 偏置为：0.799877, 损失为：0.000000
# 第881次模型优化后的参数权重：0.699979, 偏置为：0.799878, 损失为：0.000000
# 第882次模型优化后的参数权重：0.699979, 偏置为：0.799879, 损失为：0.000000
# 第883次模型优化后的参数权重：0.699980, 偏置为：0.799881, 损失为：0.000000
# 第884次模型优化后的参数权重：0.699980, 偏置为：0.799882, 损失为：0.000000
# 第885次模型优化后的参数权重：0.699980, 偏置为：0.799883, 损失为：0.000000
# 第886次模型优化后的参数权重：0.699980, 偏置为：0.799884, 损失为：0.000000
# 第887次模型优化后的参数权重：0.699980, 偏置为：0.799885, 损失为：0.000000
# 第888次模型优化后的参数权重：0.699980, 偏置为：0.799886, 损失为：0.000000
# 第889次模型优化后的参数权重：0.699981, 偏置为：0.799888, 损失为：0.000000
# 第890次模型优化后的参数权重：0.699981, 偏置为：0.799889, 损失为：0.000000
# 第891次模型优化后的参数权重：0.699981, 偏置为：0.799890, 损失为：0.000000
# 第892次模型优化后的参数权重：0.699982, 偏置为：0.799891, 损失为：0.000000
# 第893次模型优化后的参数权重：0.699982, 偏置为：0.799892, 损失为：0.000000
# 第894次模型优化后的参数权重：0.699982, 偏置为：0.799893, 损失为：0.000000
# 第895次模型优化后的参数权重：0.699982, 偏置为：0.799894, 损失为：0.000000
# 第896次模型优化后的参数权重：0.699982, 偏置为：0.799895, 损失为：0.000000
# 第897次模型优化后的参数权重：0.699983, 偏置为：0.799896, 损失为：0.000000
# 第898次模型优化后的参数权重：0.699983, 偏置为：0.799897, 损失为：0.000000
# 第899次模型优化后的参数权重：0.699983, 偏置为：0.799898, 损失为：0.000000
# 第900次模型优化后的参数权重：0.699983, 偏置为：0.799899, 损失为：0.000000
# 第901次模型优化后的参数权重：0.699983, 偏置为：0.799900, 损失为：0.000000
# 第902次模型优化后的参数权重：0.699983, 偏置为：0.799901, 损失为：0.000000
# 第903次模型优化后的参数权重：0.699983, 偏置为：0.799902, 损失为：0.000000
# 第904次模型优化后的参数权重：0.699983, 偏置为：0.799903, 损失为：0.000000
# 第905次模型优化后的参数权重：0.699984, 偏置为：0.799904, 损失为：0.000000
# ...
# 第1704次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1705次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1706次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1707次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1708次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1709次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1710次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1711次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1712次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1713次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1714次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1715次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1716次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1717次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1718次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1719次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1720次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1721次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1722次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1723次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1724次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1725次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1726次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1727次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1728次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1729次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1730次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1731次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1732次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1733次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1734次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1735次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1736次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1737次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1738次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1739次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1740次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1741次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1742次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1743次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1744次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1745次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1746次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1747次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1748次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1749次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1750次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1751次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1752次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1753次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1754次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1755次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1756次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1757次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1758次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1759次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1760次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1761次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1762次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1763次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1764次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1765次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1766次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1767次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1768次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1769次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1770次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1771次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1772次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1773次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1774次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1775次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1776次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1777次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1778次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1779次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1780次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1781次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1782次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1783次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1784次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1785次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1786次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1787次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1788次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1789次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1790次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1791次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1792次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1793次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1794次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1795次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1796次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1797次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1798次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1799次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1800次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1801次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1802次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1803次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1804次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1805次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1806次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1807次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1808次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1809次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1810次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1811次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1812次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1813次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1814次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1815次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1816次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1817次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1818次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1819次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1820次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1821次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1822次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1823次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1824次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1825次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1826次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1827次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1828次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1829次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1830次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1831次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1832次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1833次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1834次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1835次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1836次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1837次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1838次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1839次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1840次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1841次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1842次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1843次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1844次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1845次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1846次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1847次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1848次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1849次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1850次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1851次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1852次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1853次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1854次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1855次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1856次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1857次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1858次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1859次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1860次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1861次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1862次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1863次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1864次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1865次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1866次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1867次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1868次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1869次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1870次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1871次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1872次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1873次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1874次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1875次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1876次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1877次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1878次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1879次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1880次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1881次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1882次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1883次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1884次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1885次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1886次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1887次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1888次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1889次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1890次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1891次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1892次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1893次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1894次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1895次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1896次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1897次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1898次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1899次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1900次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1901次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1902次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1903次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1904次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1905次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1906次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1907次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1908次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1909次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1910次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1911次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1912次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1913次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1914次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1915次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1916次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1917次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1918次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1919次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1920次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1921次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1922次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1923次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1924次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1925次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1926次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1927次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1928次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1929次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1930次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1931次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1932次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1933次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1934次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1935次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1936次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1937次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1938次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1939次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1940次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1941次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1942次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1943次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1944次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1945次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1946次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1947次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1948次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1949次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1950次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1951次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1952次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1953次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1954次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1955次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1956次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1957次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1958次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1959次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1960次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1961次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1962次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1963次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1964次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1965次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1966次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1967次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1968次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1969次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1970次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1971次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1972次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1973次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1974次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1975次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1976次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1977次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1978次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1979次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1980次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1981次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1982次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1983次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1984次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1985次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1986次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1987次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1988次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1989次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1990次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1991次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1992次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1993次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1994次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1995次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1996次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1997次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1998次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000
# 第1999次模型优化后的参数权重：0.699999, 偏置为：0.799998, 损失为：0.000000

# %% [markdown]
# ### 实现线性回归
# 1. **学习率、步长和梯度爆炸**
#     * 学习率不应该设置过大、0~1之间的数，如果过大，导致梯度爆炸（损失、参数优化成nan）
#     * 学习率越大，达到最终比较好的效果步长越小
#     * 学习率越小，达到最终比较好的效果步长越大
#     * 一般选择较小的学习率
#
# 2. **在极端条件下，权重的值变得非常大，以至于溢出，导致`NaN`值。以下是梯度爆炸解决方案（深度神经网络当中更容易出现）**
#     * 重新设计网络
#     * 调整学习率
#     * 使用梯度截断（在训练过程中检查和限制梯度的大小）
#     * 使用激活函数
#
# 3. **模型要优化的参数必须选择`tf.Variable`定义，并且指定`trainable`参数为可训练**
#
#
# 4. **增加命名空间**
#
#     使代码结构更加清晰，TensorBoard图结构清楚

# %% [markdown]
# ### 增加变量显示
#
# 目的：在TensorBoard当中观察模型的参数、损失值等变量值的变化
#
# 1. 收集变量
#
#     * `tf.summary.scalar(name=" ", tensor)`收集损失函数和准确率等单值变量，name为变量的名字，tensor为值
#
#     * `tf.summary.histogram(name=" ",  tensor)`收集高维度的变化参数
#
#     * `tf.summary.image(name=" ", tensor)`收集输入的图片张量能显示图片
#
# 2. 合并变量写入事件文件
#
#     * `merge = tf.summary.merge_all()`
#
#     * 运行合并：`summary = sess.run(merged)`，每次迭代都需要运行
#
#     * 添加：`FileWriter.add_summary(summary, i)` i表示第几次的值
